# %%
df_cleaned = pd.read_csv("cleaned_salary_data.csv")

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(x='Gender', y='Salary', data=df_cleaned)
plt.title("Salary Distribution by Gender")
plt.show()
